# %% [markdown]
# # Vallidate the Results of the Multi Unit-Regression
#
# The multi-unit regression uses building, parcel, and zillow data to calculate the units for multi-family homes when the provided unit is missing. To validate this data first we validate the output corresponds with the expected values. Then these values are validated at the census tract level to ensure the hosting capacity analysis is being completed on reliable data.

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import os
import matplotlib.pyplot as plt

# %%
# set option to see all data frame columns
pd.set_option('display.max_columns', None)

# %%
# import Zillow data 
zillow = gpd.read_parquet("../../../../../../capstone/electrigrid/data/buildings/zillow.parquet").to_crs(epsg=4326)

# read in ca boundary to clip zillow
ca_boundary = gpd.read_file("../../../../../../capstone/electrigrid/data/ca_state_boundary.geojson").to_crs(epsg=4326)

# import multifamily homes with units 
multi_zillow_w_units = gpd.read_parquet("../../../../../../capstone/electrigrid/data/buildings/final_zillow_w_volume/multi_zillow_w_units.parquet").to_crs(epsg=4326)

# import multifamily homes with units 
keep_outliers_multi_zillow_w_units = gpd.read_parquet("../../../../../../capstone/electrigrid/data/buildings/final_zillow_w_volume/keep_outliers_multi_zillow_w_units.parquet").to_crs(epsg=4326)

# import single family homes with  adjusted units 
single_condo_zillow_w_units = gpd.read_parquet("../../../../../../capstone/electrigrid/data/buildings/final_zillow_w_volume/single_condo_zillow_w_units.parquet").to_crs(epsg=4326)

# %%
# clip Zillow to california 
zillow = zillow.clip(ca_boundary)

# %% [markdown]
# ### Validate the outputs of the unit data with the original Zillow dataset

# %%
print(f"The orginal Zillow data includes ", zillow.shape[0], "points")
# Out:
# The orginal Zillow data includes  10012568 points

# %%
# investigate the unit totals
multi_zillow = zillow[(zillow['type'] == 'Multi') & (zillow['code'] != 'RR106')]
single_zillow = zillow[zillow['type'] == 'Single']
condo_multi = zillow[(zillow['type'] == 'Multi') & (zillow['code'] == 'RR106')]

# %%
# condo data is crazy!
zillow[(zillow['type'] == 'Multi') & (zillow['code'] == 'RR106')].head(3)
# Out:
#           type  year  room    heat     cool   own  unit     value sqft_type  \
# 8104600  Multi   NaN   NaN  fossil  central  None   NaN  159515.0    living
# 8104552  Multi   NaN   NaN  fossil  central     O   NaN  229500.0    living
# 8104601  Multi   NaN   NaN  fossil  central  None   NaN  159291.0    living
#
#            sqft       ID        GEOID  p_ID    area   code  \
# 8104600  1452.0  1429921  06025012003  h279  Others  RR106
# 8104552  1452.0  1429873  06025012003  h279  Others  RR106
# 8104601  1276.0  1429922  06025012003  h279  Others  RR106
#
#                             geometry
# 8104600  POINT (-115.48046 32.67979)
# 8104552  POINT (-115.48046 32.67979)
# 8104601  POINT (-115.48046 32.67979)

# %%
print(f"There are ", multi_zillow['unit'].sum() + single_zillow.shape[0] + condo_multi.shape[0], "units before the regression of multifamily homes.")
# Out:
# There are  13107697.0 units before the regression of multifamily homes.

# %%
print(f"The regressed Zillow data is", multi_zillow_w_units.shape[0] + single_condo_zillow_w_units.shape[0] ,"points")
# Out:
# The regressed Zillow data is 9940002 points

# %%
print(f"The number of homes calculated in California by unit (when dropping outliers):", single_condo_zillow_w_units['total_unit'].sum() + multi_zillow_w_units['total_unit'].sum())
# Out:
# The number of homes calculated in California by unit (when dropping outliers): 20473622.0

# %%
print(f'The number of homes calculated in California by unit (when keeping outliers): ', single_condo_zillow_w_units['total_unit'].sum() + keep_outliers_multi_zillow_w_units['total_unit'].sum())
# Out:
# The number of homes calculated in California by unit (when keeping outliers):  12505709.0

# %% [markdown]
# # Investigate differences

# %%
print(f"Maximum units for multi-family homes before the regression",multi_zillow['unit'].max())
# Out:
# Maximum units for multi-family homes before the regression 6857.0

# %%
print(f"Maximum units for the multi-family homes after the regression", multi_zillow_w_units['total_unit'].max())
# Out:
# Maximum units for the multi-family homes after the regression 32508.0

# %%
multi_zillow_w_units[multi_zillow_w_units['total_unit'] > 20000]
# Out:
#        parcel_ID source                            id  height_m       var  \
# 70056    1741158    osm                    1076648548  4.239654  1.235935
# 70115    1741991     ms  UnitedStates_023010033_48507  7.166322  0.922174
# 70151    1742546     ms  UnitedStates_023010033_40271  2.930069  0.692705
#
#       region                                               bbox   type  year  \
# 70056    USA  {'xmax': -121.32035999999997, 'xmin': -121.320...  Multi   NaN
# 70115    USA  {'xmax': -121.07778351764603, 'xmin': -121.078...  Multi   NaN
# 70151    USA  {'xmax': -121.09698268310447, 'xmin': -121.097...  Multi   NaN
#
#        room    heat     cool   own       value sqft_type      sqft       ID  \
# 70056   NaN  fossil  central  None  18857590.0    living  203928.0  5412257
# 70115   2.0    elec     None  None    635342.0    living    4612.0  5393461
# 70151   2.0    elec     None     O    908431.0    living    3217.0  5423464
#
#              GEOID p_ID     area   code  zillow_index  total_unit     area_m2  \
# 70056  06061021403   80  PGE/SCE  RI103       3793394     25898.0  277.320948
# 70115  06061020300  612  PGE/SCE  RI103       3783944     32508.0  602.098473
# 70151  06061021501  341  PGE/SCE  RI102       3802682     21978.0  139.837178
#
#          volume_m3  total_volume_m3                     geometry
# 70056  1175.744752     1.873520e+06  POINT (-121.31155 38.88203)
# 70115  4314.831385     1.800838e+06  POINT (-121.06943 38.91169)
# 70151   409.732608     4.993344e+05  POINT (-121.08896 38.92205)

# %% [markdown]
# From code, know they are triplexes (RI102) and quadruplexes (RI103)
#
# Explore the number of units in the original Zillow df

# %%
zillow[zillow.index.isin([3793394, 3783944, 3802682])]
# Out:
#           type  year  room    heat     cool   own   unit       value  \
# 3783944  Multi   NaN   2.0    elec     None  None    4.0    635342.0
# 3802682  Multi   NaN   2.0    elec     None     O    4.0    908431.0
# 3793394  Multi   NaN   NaN  fossil  central  None  240.0  18857590.0
#
#         sqft_type      sqft       ID        GEOID p_ID     area   code  \
# 3783944    living    4612.0  5393461  06061020300  612  PGE/SCE  RI103
# 3802682    living    3217.0  5423464  06061021501  341  PGE/SCE  RI102
# 3793394    living  203928.0  5412257  06061021403   80  PGE/SCE  RI103
#
#                             geometry
# 3783944  POINT (-121.06986 38.90460)
# 3802682  POINT (-121.08477 38.91939)
# 3793394  POINT (-121.30563 38.88513)

# %% [markdown]
# Look slike the quadruplexes were accurate, whereas the triplex was not?

# %%
multi_zillow_w_units[multi_zillow_w_units['total_unit'] > 10000]
# Out:
#         parcel_ID source                             id   height_m       var  \
# 38977      543106    osm                      582556168   4.224887  0.281700
# 66969     1609804     ms  UnitedStates_023012130_128213   4.362795  1.790771
# 69804     1729868     ms  UnitedStates_023010211_317363   5.165205  0.781673
# 70056     1741158    osm                     1076648548   4.239654  1.235935
# 70115     1741991     ms   UnitedStates_023010033_48507   7.166322  0.922174
# 70151     1742546     ms   UnitedStates_023010033_40271   2.930069  0.692705
# 70165     1742770     ms     UnitedStates_023010033_283   6.405213  1.203548
# 70507     1752557    osm                      825933825  11.080114  1.921150
# 315641    5771986    osm                      270490185   7.112334  1.765728
# 323358    6243525    osm                      270490161   8.857489  4.040596
# 338736    6660303     ms   UnitedStates_023010211_98948   5.393303  1.452103
# 465780    9246371    osm                      385951507   6.916929  1.941668
# 465781    9246372    osm                      385951507   6.916929  1.941668
# 465782    9246373    osm                      385951507   6.916929  1.941668
# 465783    9246374    osm                      385951507   6.916929  1.941668
# 465784    9246375    osm                      385951507   6.916929  1.941668
# 465785    9246376    osm                      385951507   6.916929  1.941668
# 465786    9246377    osm                      385951507   6.916929  1.941668
# 465787    9246378    osm                      385951507   6.916929  1.941668
# 465788    9246379    osm                      385951507   6.916929  1.941668
# 465789    9246380    osm                      385951507   6.916929  1.941668
# 465790    9246381    osm                      385951507   6.916929  1.941668
# 465791    9246382    osm                      385951507   6.916929  1.941668
# 465792    9246383    osm                      385951507   6.916929  1.941668
# 465793    9246384    osm                      385951507   6.916929  1.941668
# 465794    9246385    osm                      385951507   6.916929  1.941668
# 465795    9246386    osm                      385951507   6.916929  1.941668
# 465796    9246387    osm                      385951507   6.916929  1.941668
# 465797    9246388    osm                      385951507   6.916929  1.941668
# 465798    9246389    osm                      385951507   6.916929  1.941668
# 465799    9246390    osm                      385951507   6.916929  1.941668
# 465800    9246391    osm                      385951507   6.916929  1.941668
# 465801    9246392    osm                      385951507   6.916929  1.941668
# 465802    9246393    osm                      385951507   6.916929  1.941668
# 465803    9246394    osm                      385951507   6.916929  1.941668
# 474897    9545125    osm                      378100141   5.608708  1.320063
#
#        region                                               bbox   type  \
# 38977     USA  {'xmax': -120.4548948, 'xmin': -120.4551705999...  Multi
# 66969     USA  {'xmax': -119.07907524101593, 'xmin': -119.079...  Multi
# 69804     USA  {'xmax': -121.00026477736984, 'xmin': -121.000...  Multi
# 70056     USA  {'xmax': -121.32035999999997, 'xmin': -121.320...  Multi
# 70115     USA  {'xmax': -121.07778351764603, 'xmin': -121.078...  Multi
# 70151     USA  {'xmax': -121.09698268310447, 'xmin': -121.097...  Multi
# 70165     USA  {'xmax': -121.09756670130248, 'xmin': -121.097...  Multi
# 70507     USA  {'xmax': -121.060198, 'xmin': -121.060348, 'ym...  Multi
# 315641    USA  {'xmax': -117.1681442, 'xmin': -117.168349, 'y...  Multi
# 323358    USA  {'xmax': -117.16821460000001, 'xmin': -117.168...  Multi
# 338736    USA  {'xmax': -121.50562354388013, 'xmin': -121.505...  Multi
# 465780    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465781    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465782    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465783    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465784    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465785    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465786    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465787    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465788    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465789    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465790    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465791    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465792    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465793    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465794    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465795    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465796    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465797    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465798    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465799    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465800    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465801    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465802    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 465803    USA  {'xmax': -122.2605461, 'xmin': -122.2607557999...  Multi
# 474897    USA  {'xmax': -121.83032059999998, 'xmin': -121.830...  Multi
#
#           year  room    heat     cool   own       value sqft_type      sqft  \
# 38977      NaN   NaN    None     None     I      9736.0    living    4320.0
# 66969   2022.0   5.0  others   others  None    427133.0    living    2109.0
# 69804   1979.0   5.0    None     None  None   1945548.0    living    9408.0
# 70056      NaN   NaN  fossil  central  None  18857590.0    living  203928.0
# 70115      NaN   2.0    elec     None  None    635342.0    living    4612.0
# 70151      NaN   2.0    elec     None     O    908431.0    living    3217.0
# 70165      NaN   3.0  fossil  central  None    465000.0    living    2227.0
# 70507      NaN   7.0    None     None  None    395000.0    living    3784.0
# 315641  2004.0   NaN  fossil  central  None    954508.0      None       NaN
# 323358  2004.0   NaN  fossil  central  None    736904.0      None       NaN
# 338736     NaN   NaN    None     None  None  21802872.0      None       NaN
# 465780     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465781     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465782     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465783     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465784     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465785     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465786     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465787     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465788     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465789     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465790     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465791     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465792     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465793     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465794     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465795     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465796     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465797     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465798     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465799     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465800     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465801     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465802     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 465803     NaN   2.0  fossil     None  None    478258.0    living    1425.0
# 474897     NaN   NaN    None     None  None    173977.0      None       NaN
#
#              ID        GEOID   p_ID     area   code  zillow_index  total_unit  \
# 38977    580321  06009000122    129  PGE/SCE  RI109        495938     16464.0
# 66969   1718760  06029003220    147  PGE/SCE  RI101       1440374     15158.0
# 69804   1002152  06017030810    678  PGE/SCE  RI103        861990     18848.0
# 70056   5412257  06061021403     80  PGE/SCE  RI103       3793394     25898.0
# 70115   5393461  06061020300    612  PGE/SCE  RI103       3783944     32508.0
# 70151   5423464  06061021501    341  PGE/SCE  RI102       3802682     21978.0
# 70165   5423175  06061021501    575  PGE/SCE  RI101       3802438     12257.0
# 70507   4519994  06057000602     81  PGE/SCE  RI104       3145029     13005.0
# 315641  5898085  06065050702   1208  PGE/SCE  RI104       4102993     15714.0
# 323358  5898096  06065050702   1208  PGE/SCE  RI104       4103004     10864.0
# 338736  6659344  06067007011  h1079   Others  RI112       9572266     12736.0
# 465780  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465781  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465782  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465783  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465784  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465785  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465786  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465787  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465788  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465789  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465790  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465791  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465792  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465793  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465794  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465795  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465796  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465797  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465798  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465799  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465800  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465801  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465802  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 465803  9210127  06081609201    165  PGE/SCE  RI112       5650504     13824.0
# 474897  9751452  06085512023     41  PGE/SCE  RI104       6106514     10800.0
#
#             area_m2    volume_m3  total_volume_m3                     geometry
# 38977    236.116360   997.564915     9.975649e+02  POINT (-120.45512 38.13823)
# 66969   1874.664320  8178.775889     3.337407e+04  POINT (-119.08108 35.28530)
# 69804    292.316774  1509.875924     2.316813e+06  POINT (-121.00006 38.69217)
# 70056    277.320948  1175.744752     1.873520e+06  POINT (-121.31155 38.88203)
# 70115    602.098473  4314.831385     1.800838e+06  POINT (-121.06943 38.91169)
# 70151    139.837178   409.732608     4.993344e+05  POINT (-121.08896 38.92205)
# 70165    573.526316  3673.558149     9.678237e+05  POINT (-121.08808 38.92943)
# 70507     97.263434  1077.689976     1.913469e+06  POINT (-121.06990 39.21575)
# 315641   486.073106  3457.114402     9.779628e+03  POINT (-117.16857 33.63411)
# 323358   507.328874  4493.659737     4.493660e+03  POINT (-117.16834 33.63302)
# 338736    54.490829   293.885574     5.701870e+04  POINT (-121.50619 38.61529)
# 465780   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465781   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465782   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465783   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465784   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465785   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465786   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465787   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465788   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465789   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465790   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465791   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465792   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465793   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465794   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465795   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465796   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465797   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465798   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465799   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465800   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465801   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465802   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 465803   169.637169  1173.368294     1.428005e+04  POINT (-122.26091 37.50295)
# 474897   101.812436   571.036264     5.203895e+04  POINT (-121.82946 37.25690)

# %%
zillow[zillow.index.isin([13824.0])]
# Out:
#          type    year  room  heat  cool own  unit      value sqft_type  \
# 13824  Single  1910.0   2.0  None  None   I   1.0  1564761.0    living
#
#          sqft     ID        GEOID p_ID     area   code  \
# 13824  1078.0  15452  06001400300  574  PGE/SCE  RR101
#
#                           geometry
# 13824  POINT (-122.25757 37.83831)

# %%
zillow[zillow.index.isin([5650504])]
# Out:
#           type  year  room    heat  cool   own  unit     value sqft_type  \
# 5650504  Multi   NaN   2.0  fossil  None  None  24.0  478258.0    living
#
#            sqft       ID        GEOID p_ID     area   code  \
# 5650504  1425.0  9210127  06081609201  165  PGE/SCE  RI112
#
#                             geometry
# 5650504  POINT (-122.26084 37.50303)

# %%
import geopandas as gpd

# %%
final = gpd.read_parquet("../../../../../../capstone/electrigrid/data/final_building.parquet")

# %%
final.plot()
# Out:
# <Axes: >

# %%
len(final)
# Out:
# 11489502
